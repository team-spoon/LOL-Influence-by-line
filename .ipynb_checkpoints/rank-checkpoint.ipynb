# %%
import requests
import pprint
import pandas as pd

pp = pprint.PrettyPrinter(indent=4)
api_key = 'RGAPI-936fbe44-a27a-4aaf-96c0-9a9ae3df5159'
game_id = 'KR_6261112670'

request_header={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": api_key
}

summoner_api = 'https://asia.api.riotgames.com/lol/match/v5/matches/' + game_id
r = requests.get(summoner_api,headers=request_header)
df=pd.DataFrame(r.json())
part_df = pd.DataFrame(df['info']['participants']);

# 조건 : 이겼는가
is_win = part_df['win']==True
part_df[is_win]
# Out:
#    allInPings  assistMePings  assists  baitPings  baronKills  basicPings  \
# 5           0              0       10          0           0           0
# 6           2              8        6          2           0           0
# 7           0              0       15          0           1           0
# 8           0              1       12          1           0           0
# 9           0              0       11          0           1           0
#
#    bountyLevel                                         challenges  \
# 5            0  {'12AssistStreakCount': 0, 'abilityUses': 377,...
# 6            2  {'12AssistStreakCount': 0, 'abilityUses': 484,...
# 7            0  {'12AssistStreakCount': 0, 'abilityUses': 439,...
# 8            7  {'12AssistStreakCount': 0, 'abilityUses': 280,...
# 9            1  {'12AssistStreakCount': 0, 'abilityUses': 165,...
#
#    champExperience  champLevel  ...  turretKills turretTakedowns  turretsLost  \
# 5            17697          17  ...            2               2            4
# 6            17599          17  ...            4               5            4
# 7            19882          18  ...            2               3            4
# 8            18169          17  ...            0               2            4
# 9            11734          14  ...            0               1            4
#
#    unrealKills  visionClearedPings  visionScore  visionWardsBoughtInGame  \
# 5            0                   0           34                        6
# 6            0                   0           50                        7
# 7            0                   0           47                        3
# 8            0                   0           35                        4
# 9            0                   0          127                        9
#
#    wardsKilled  wardsPlaced   win
# 5            3           11  True
# 6           12            9  True
# 7            2           14  True
# 8           10           11  True
# 9           26           66  True
#
# [5 rows x 121 columns]

# %%
lines = ['TOP', 'BOTTOM', 'MIDDLE', 'JUNGLE', 'UTILITY']
# doco_line = part_df['individualPosition']=='BOTTOM'
# pd.DataFrame(part_df[is_win & doco_line])['challenges'].iloc[0]['kda']
rank = dict()
# 라인별 KDA 구하기
for line in lines:
    doco_line = part_df['individualPosition']==line
    kda = pd.DataFrame(part_df[is_win & doco_line])['challenges'].iloc[0]['kda']
    rank[line] = kda

# 라인별 KDA 정렬하기
sorted_rank = dict(sorted(rank.items(), key = lambda item: item[1], reverse = True))
for key, val in sorted_rank.items():
    pp.pprint("key = {key}, value={value}".format(key=key,value=val))
# Out:
# 'key = BOTTOM, value=6'
# 'key = MIDDLE, value=4.4'
# 'key = TOP, value=3'
# 'key = UTILITY, value=2.6666666666666665'
# 'key = JUNGLE, value=2.6'

# %%
import matplotlib.pyplot as plt

labels = []
ratio = []

for key, val in sorted_rank.items():
    labels.append(key)
    ratio.append(val)
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
